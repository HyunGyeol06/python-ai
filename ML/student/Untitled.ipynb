# %%
import pandas as pd
import numpy as np

train_x = pd.read_csv("studentscore_X_train.csv")
test_x = pd.read_csv("studentscore_X_test.csv")
train_y = pd.read_csv("studentscore_Y_train.csv")


display(train_x)
display(train_y)
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1714     GP   F   18       U     GT3       T     4     3     other
# 1         1254     GP   F   17       U     GT3       T     4     3    health
# 2         1639     GP   F   16       R     GT3       T     4     4    health
# 3         1118     GP   M   16       U     GT3       T     4     4  services
# 4         1499     GP   M   19       U     GT3       T     3     2  services
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 673       1074     GP   M   15       U     GT3       T     4     4  services
# 674       1044     GP   M   15       R     GT3       T     4     4     other
# 675       1078     GP   M   17       U     LE3       T     4     4     other
# 676       1055     MS   M   17       R     GT3       T     1     1     other
# 677       1394     GP   F   17       U     GT3       T     3     2    health
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
stdId = x_test['StudentID']
drop_col = ["StudentID"]

train_x_drop = train_x.drop(columns=drop_col)
test_x_drop = test_x.drop(columns=drop_col)
y_train_target = y_train['G3']

x_train_dum = pd.get_dummies(train_x_drop)
x_test_dum = pd.get_dummies(test_x_drop)[x_train_dum.columns]

xtr, xt, ytr, yt = train_test_split(x_train_dum, y_train_target)

rf = RandomForestRegressor(random_state = 34)
rf.fit(xtr, ytr)

y_validation_pred = rf.predict(xt)

# %%
print("validation mse", mean_squared_error(yt, y_validation_pred))
print("validation rmse", np.sqrt(mean_squared_error(yt, y_validation_pred)))
print("validation r2", r2_score(yt, y_validation_pred))
# Out:
# validation mse 1.7759958823529414
# validation rmse 1.3326649550254337
# validation r2 0.8934398783386793

# %%
test_pred = rf.predict(x_test_dum)

result = pd.DataFrame({"StudentID" : stdId, "G3" : test_pred})

result
# Out:
#      StudentID     G3
# 0         1000  16.29
# 1         1008  11.05
# 2         1013  14.24
# 3         1014   7.58
# 4         1017  11.01
# ..         ...    ...
# 361       2032  15.59
# 362       2034  12.15
# 363       2035  16.36
# 364       2036   0.97
# 365       2037  14.51
#
# [366 rows x 2 columns]
